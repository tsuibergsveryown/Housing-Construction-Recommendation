# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import r2_score

# %matplotlib inline

# %% [markdown]
# ## Read .csv Files
# ____

# %%
df_test = pd.read_csv('datasets/test_clean.csv')
df_test1 = pd.read_csv('datasets/test.csv')
df_test2 = pd.read_csv('datasets/test_clean_final.csv')

# %%
df_test
# Out:
#        id        pid  ms_subclass  ms_zoning  lot_frontage  lot_area  street  \
# 0    2658  902301120          190          2          69.0      9142       0
# 1    2718  905108090           90          3           0.0      9662       0
# 2    2414  528218130           60          3          58.0     17104       0
# 3    1989  902207150           30          2          60.0      8520       0
# 4     625  535105100           20          3           0.0      9500       0
# ..    ...        ...          ...        ...           ...       ...     ...
# 840  1662  527377110           60          3          80.0      8000       0
# 841  1234  535126140           60          3          90.0     14670       0
# 842  1373  904100040           20          3          55.0      8250       0
# 843  1672  527425140           20          3          60.0      9000       0
# 844  1939  535327160           20          3          70.0      8400       0
#
# ...

# %%
df_test1
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2658  902301120          190        RM          69.0      9142   Pave
# 1    2718  905108090           90        RL           NaN      9662   Pave
# 2    2414  528218130           60        RL          58.0     17104   Pave
# 3    1989  902207150           30        RM          60.0      8520   Pave
# 4     625  535105100           20        RL           NaN      9500   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 873  1662  527377110           60        RL          80.0      8000   Pave
# 874  1234  535126140           60        RL          90.0     14670   Pave
# 875  1373  904100040           20        RL          55.0      8250   Pave
# 876  1672  527425140           20        RL          60.0      9000   Pave
# 877  1939  535327160           20        RL          70.0      8400   Pave
#
# ...

# %%
df_test2
# Out:
#      totrms_abvgrd  fireplace_qu  year_remod/add  full_bath  garage_finish  \
# 0                9           0.0            1950          2            1.0
# 1               10           0.0            1977          2            3.0
# 2                7           4.0            2006          2            2.0
# 3                5           0.0            2006          1            1.0
# 4                6           4.0            1963          1            2.0
# ..             ...           ...             ...        ...            ...
# 840              8           3.0            1974          2            1.0
# 841              9           4.0            1999          2            2.0
# 842              5           3.0            1968          1            1.0
# 843              5           0.0            1971          1            1.0
# 844              5           3.0            1955          1            1.0
#
# ...

# %%
df_test2 = df_test2.join(df_test['id'])

# %%
df_test2
# Out:
#      totrms_abvgrd  fireplace_qu  year_remod/add  full_bath  garage_finish  \
# 0                9           0.0            1950          2            1.0
# 1               10           0.0            1977          2            3.0
# 2                7           4.0            2006          2            2.0
# 3                5           0.0            2006          1            1.0
# 4                6           4.0            1963          1            2.0
# ..             ...           ...             ...        ...            ...
# 840              8           3.0            1974          2            1.0
# 841              9           4.0            1999          2            2.0
# 842              5           3.0            1968          1            1.0
# 843              5           0.0            1971          1            1.0
# 844              5           3.0            1955          1            1.0
#
# ...

# %%
# Create a new dataframe with only 'id' & 'saleprice_pred' columns
df_test3 = pd.DataFrame(df_test2, columns = ['id', 'saleprice_pred'])
df_test3
# Out:
#        id  saleprice_pred
# 0    2658   126203.240279
# 1    2718   188983.595647
# 2    2414   203193.737021
# 3    1989   124054.148674
# 4     625   169237.058223
# ..    ...             ...
# 840  1662   173640.496423
# 841  1234   199966.070908
# 842  1373   132785.334521
# 843  1672   110849.396825
# 844  1939   117317.098435
#
# [845 rows x 2 columns]

# %%
# Rename 'id' to 'Id', and 'saleprice_pred' to 'SalePrice'
df_test3 = df_test3.rename(columns={
    'id': 'Id',
    'saleprice_pred': 'SalePrice'
})
df_test3
# Out:
#        Id      SalePrice
# 0    2658  126203.240279
# 1    2718  188983.595647
# 2    2414  203193.737021
# 3    1989  124054.148674
# 4     625  169237.058223
# ..    ...            ...
# 840  1662  173640.496423
# 841  1234  199966.070908
# 842  1373  132785.334521
# 843  1672  110849.396825
# 844  1939  117317.098435
#
# [845 rows x 2 columns]

# %%
# Export df_test3 
df_test3.to_csv('datasets/Kaggle_Submission_df_test3.csv', index=False)

# %%
df_test_1 = pd.read_csv('datasets/df_test_1.csv')

# %%
df_test_1 = df_test_1.rename({
    'id':'Id'
})
df_test_1
# Out:
#        id
# 0    2658
# 1    2718
# 2    2414
# 3    1989
# 4     625
# ..    ...
# 873  1662
# 874  1234
# 875  1373
# 876  1672
# 877  1939
#
# [878 rows x 1 columns]

# %%
df_test3
# Out:
#        Id      SalePrice
# 0    2658  126203.240279
# 1    2718  188983.595647
# 2    2414  203193.737021
# 3    1989  124054.148674
# 4     625  169237.058223
# ..    ...            ...
# 840  1662  173640.496423
# 841  1234  199966.070908
# 842  1373  132785.334521
# 843  1672  110849.396825
# 844  1939  117317.098435
#
# [845 rows x 2 columns]

# %%
# outer joined df_test_1 with df_test3
result = pd.merge(df_test1, df_test3, how='outer', on="Id")
result
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    2658  902301120          190        RM          69.0      9142   Pave
# 1    2718  905108090           90        RL           NaN      9662   Pave
# 2    2414  528218130           60        RL          58.0     17104   Pave
# 3    1989  902207150           30        RM          60.0      8520   Pave
# 4     625  535105100           20        RL           NaN      9500   Pave
# ..    ...        ...          ...       ...           ...       ...    ...
# 873  1662  527377110           60        RL          80.0      8000   Pave
# 874  1234  535126140           60        RL          90.0     14670   Pave
# 875  1373  904100040           20        RL          55.0      8250   Pave
# 876  1672  527425140           20        RL          60.0      9000   Pave
# 877  1939  535327160           20        RL          70.0      8400   Pave
#
# ...

# %%
result = result[['Id', 'SalePrice']]

# %%
result
# Out:
#        Id      SalePrice
# 0    2658  126203.240279
# 1    2718  188983.595647
# 2    2414  203193.737021
# 3    1989  124054.148674
# 4     625  169237.058223
# ..    ...            ...
# 873  1662  173640.496423
# 874  1234  199966.070908
# 875  1373  132785.334521
# 876  1672  110849.396825
# 877  1939  117317.098435
#
# [878 rows x 2 columns]

# %%
result = result.fillna(0)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 878 entries, 0 to 877
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         878 non-null    int64
#  1   SalePrice  878 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 20.6 KB

# %%
# Export result 
result.to_csv('datasets/Kaggle_Submission_TSUI.csv', index=False)
